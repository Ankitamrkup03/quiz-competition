# %%
print("Mathematics Quiz")
question1 = "Who is president of USA?"
options1 = "a.Myslef\nb. His dad\nc. His mom\nd. Barack Obama\n"
print(question1)
print(options1)

while True:
    response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

    if response == "d":
        break
    else:
        print("Incorrect!!! Try again.")

        while True:
            response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

            if response == "d":
                stop = True
                break
            else:
                print("Incorrect!!! You ran out of your attempts")
                stop = True
                break
        if stop:
            break

# DO the same for the next questions of your round (copy-paste-copy-paste).
# At the end of the round, paste the following code for the bonus question.

# Now the program will ask the user to go for the bonus question or not

while True:
    bonus = input("your answer is correct.Would you like to give a try to the bonus question?\nHit 'y' for yes and 'n' for no.\n")

    if bonus == "y":
        print("Who invented Facebook?")
        print("a. Me\nb. His dad\nc. Mark Zuckerberg\nd. Aliens")

        while True:
            response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

            if response == "c":
                break
            else:
                print("Incorrect!!! Try again.")

            while True:
                response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")


                if response == "c":
                    stop = True
                    break
                else:
                    print("Incorrect!!! You ran out of your attempts")
                    stop = True
                    break
            if stop:
                break
                  
        break
    elif bonus == "n":
        print("end the game")
        break
    else:
        print("INVALID INPUT!!! Only hit 'y' or 'n' for your response")


while True:
    bonus = input("your answer is correct.Would you like to give a try to the bonus question?\nHit 'y' for yes and 'n' for no.\n")

    if bonus == "y":
        print("Which of the following states is not located in the North")
        print("a. Jharkhand\nb. Jammu and Kashmir\nc. Odisha\nd. Haryana")

        while True:
            response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

            if response == "a":
                break
            else:
                print("Incorrect!!! Try again.")

            while True:
                response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")


                if response == "a":
                    stop = True
                    break
                else:
                    print("Incorrect!!! You ran out of your attempts")
                    stop = True
                    break
            if stop:
                  break
        break
    elif bonus == "n":
        print("end the game")
        break
    else:
        print("INVALID INPUT!!! Only hit 'y' or 'n' for your response")
        break
                
while True:
    bonus = input("your answer is correct.Would you like to give a try to the bonus question?\nHit 'y' for yes and 'n' for no.\n")

    if bonus == "y":
        print("One kilobyte is equal to:")
        print("a. 1000\nb. 1024\nc. 100\nd. 1026")

        while True:
            response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

            if response == "b":
                break
            else:
                print("Incorrect!!! Try again.")

            while True:
                response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")


                if response == "b":
                    stop = True
                    break
                else:
                    print("Incorrect!!! You ran out of your attempts")
                    stop = True
                    break
            if stop:
                break
                  
        break
    elif bonus == "n":
        print("end the game")
        break
    else:
        print("INVALID INPUT!!! Only hit 'y' or 'n' for your response")
        
while True:
    bonus = input("your answer is correct.Would you like to give a try to the bonus question?\nHit 'y' for yes and 'n' for no.\n")

    if bonus == "y":
        print("Which was the 1st non Test playing country to beat India in an international match")
        print("a. Canada\nb. Sri Lanka\nc. Zimbabwe\nd. East Africa")

        while True:
            response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")

            if response == "b":
                break
            else:
                print("Incorrect!!! Try again.")

            while True:
                response = input("Hit 'a', 'b', 'c' or 'd' for your answer\n")


                if response == "b":
                    stop = True
                    break
                else:
                    print("Incorrect!!! You ran out of your attempts")
                    stop = True
                    break
            if stop:
                break
        break
    elif bonus == "n":
        print("end the game")
        break
    else:
        print("INVALID INPUT!!! Only hit 'y' or 'n' for your response")
# Out:
# Mathematics Quiz
# Who is president of USA?
# a.Myslef
# b. His dad
# c. His mom
# d. Barack Obama
#
# Hit 'a', 'b', 'c' or 'd' for your answer
# d
# your answer is correct.Would you like to give a try to the bonus question?
# Hit 'y' for yes and 'n' for no.
# y
# Who invented Facebook?
# a. Me
# b. His dad
# c. Mark Zuckerberg
# d. Aliens
# Hit 'a', 'b', 'c' or 'd' for your answer
# c
# your answer is correct.Would you like to give a try to the bonus question?
# Hit 'y' for yes and 'n' for no.
# y
# Which of the following states is not located in the North
# a. Jharkhand
# b. Jammu and Kashmir
# c. Odisha
# d. Haryana
# Hit 'a', 'b', 'c' or 'd' for your answer
# a
# your answer is correct.Would you like to give a try to the bonus question?
# Hit 'y' for yes and 'n' for no.
# y
# One kilobyte is equal to:
# a. 1000
# b. 1024
# c. 100
# d. 1026
# Hit 'a', 'b', 'c' or 'd' for your answer
# b
# your answer is correct.Would you like to give a try to the bonus question?
# Hit 'y' for yes and 'n' for no.
# n
# end the game
